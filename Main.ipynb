# %%
import dash
from dash.dependencies import Input, Output
import dash_core_components as dcc
import dash_html_components as html
import pandas as pd
import plotly.graph_objs as go
import import_ipynb
from Topic_Extraction import topic_extraction,create_dict_list_of_topics 
import time

global final_reddit_topic_df
global top_post_df
global dict_topics

# %%
app = dash.Dash()
reddit_post_df = pd.read_csv('500_Topics.csv')
sort_reddit_post_df = reddit_post_df.sort_values(by = ['Comment_Num'],ascending = False)
final_post_df = sort_reddit_post_df.head(5)
final_topic_df = topic_extraction(final_post_df)
top_post_df = final_topic_df[['Title','Score','Url','Dominant_Topic','timestamp']].sort_values(by=['Score'], ascending=False)
dict_topics = create_dict_list_of_topics(final_topic_df)
dict_topics
# Out:
# Topic_Extraction.ipynb:27: FutureWarning:
#
#
# The current behaviour of 'Series.argmax' is deprecated, use 'idxmax'
# instead.
# The behavior of 'argmax' will be corrected to return the positional
# maximum in the future. For now, use 'series.values.argmax' or
# 'np.argmax(np.array(values))' to get the position of the maximum
# row.
#
# Topic_Extraction.ipynb:30: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# [{'value': 'students,free,low,data,break',
#   'label': 'students,free,low,data,break'},
#  {'value': 'science,users,tier,break,interview',
#   'label': 'science,users,tier,break,interview'},
#  {'value': 'beware,tool,hunger,reality,vs',
#   'label': 'beware,tool,hunger,reality,vs'},
#  {'value': 'data,pandas,companies,vs,toughest',
#   'label': 'data,pandas,companies,vs,toughest'},
#  {'value': 'masters,dataframes,phd,perception,medium',
#   'label': 'masters,dataframes,phd,perception,medium'}]

# %%
def dict_topic_list(dict_list):
    topic_list = []
    for d in dict_list:
        topic_list.append(d.get('value'))
    print(topic_list)
    return topic_list

# %%
'''app.layout = html.Div([
    html.H1('Auto Generated FAQ'),
    html.H3('Select Topics'),
    dcc.Dropdown(
        id='my-dropdown',
        options=dict_topics,
        multi=True,
        value= dict_topic_list(dict_topics)
    ),
    # html.H3('Trending Topics'),
    dcc.Graph(
        id='top_topics'
    ),
    dcc.Graph(
        id='top_topics_timeline'
    ),
    html.H1('FAQ This Week'),
    html.Table(id= 'my-table')
])


@app.callback(Output('top_topics_timeline', 'figure'),[Input('my-dropdown', 'value')])
def update_graph(selected_dropdown_value):
    top_topic_filtered_df = top_post_df.copy()
    top_topic_filtered_df = top_post_filtered(top_topic_filtered_df, selected_dropdown_value)
    data = timeline_top_post_filtered(top_topic_filtered_df,selected_dropdown_value)
    # Edit the layout

    layout = dict(title='Top Topics Timeline',
                  xaxis=dict(title='Month'),
                  yaxis=dict(title='count posts'),
                  )
    figure = dict(data=data,layout=layout)
    return figure
@app.callback(Output('my-table', 'children'), [Input('my-dropdown', 'value')])
def generate_table(selected_dropdown_value,max_rows=10):
    top_post_filtered_df= top_post_df.copy()
    top_post_filtered_df= top_post_filtered(top_post_filtered_df,selected_dropdown_value)
    return [html.Tr([html.Th(col) for col in top_post_filtered_df.columns])] + [html.Tr([html.Td(html.A('click', href=top_post_filtered_df.iloc[i][col])) if col == 'url' else html.Td(top_post_filtered_df.iloc[i][col]) for col in top_post_filtered_df.columns]) for i in range(min(len(top_post_filtered_df), max_rows))]

def convertTuple(tup):
    str =  ','.join(tup)
    return str

def top_post_filtered(top_post_filtered_df,selected_dropdown_value):
    print(selected_dropdown_value)
    # if selected_dropdown_value is None:
    #     selected_dropdown_value = dict_topics
    top_post_filtered_df['dominant_topic_text'] = top_post_df['dominanttopic'].apply(convertTuple)
    top_post_filtered_df = top_post_filtered_df[(top_post_filtered_df['dominant_topic_text'].isin(selected_dropdown_value))]
    top_post_filtered_df = top_post_filtered_df.drop(columns=['dominanttopic'])
    return top_post_filtered_df
'''
# Out:
# "app.layout = html.Div([\n    html.H1('Auto Generated FAQ'),\n    html.H3('Select Topics'),\n    dcc.Dropdown(\n        id='my-dropdown',\n        options=dict_topics,\n        multi=True,\n        value= dict_topic_list(dict_topics)\n    ),\n    # html.H3('Trending Topics'),\n    dcc.Graph(\n        id='top_topics'\n    ),\n    dcc.Graph(\n        id='top_topics_timeline'\n    ),\n    html.H1('FAQ This Week'),\n    html.Table(id= 'my-table')\n])\n\n\n@app.callback(Output('top_topics_timeline', 'figure'),[Input('my-dropdown', 'value')])\ndef update_graph(selected_dropdown_value):\n    top_topic_filtered_df = top_post_df.copy()\n    top_topic_filtered_df = top_post_filtered(top_topic_filtered_df, selected_dropdown_value)\n    data = timeline_top_post_filtered(top_topic_filtered_df,selected_dropdown_value)\n    # Edit the layout\n\n    layout = dict(title='Top Topics Timeline',\n                  xaxis=dict(title='Month'),\n                  yaxis=dict(title='count posts'),\n                  )\n    figure = dict(data=data,layout=layout)\n    return figure\n@app.callback(Output('my-table', 'children'), [Input('my-dropdown', 'value')])\ndef generate_table(selected_dropdown_value,max_rows=10):\n    top_post_filtered_df= top_post_df.copy()\n    top_post_filtered_df= top_post_filtered(top_post_filtered_df,selected_dropdown_value)\n    return [html.Tr([html.Th(col) for col in top_post_filtered_df.columns])] + [html.Tr([html.Td(html.A('click', href=top_post_filtered_df.iloc[i][col])) if col == 'url' else html.Td(top_post_filtered_df.iloc[i][col]) for col in top_post_filtered_df.columns]) for i in range(min(len(top_post_filtered_df), max_rows))]\n\ndef convertTuple(tup):\n    str =  ','.join(tup)\n    return str\n\ndef top_post_filtered(top_post_filtered_df,selected_dropdown_value):\n    print(selected_dropdown_value)\n    # if selected_dropdown_value is None:\n    #     selected_dropdown_value = dict_topics\n    top_post_filtered_df['dominant_topic_text'] = top_post_df['dominanttopic'].apply(convertTuple)\n    top_post_filtered_df = top_post_filtered_df[(top_post_filtered_df['dominant_topic_text'].isin(selected_dropdown_value))]\n    top_post_filtered_df = top_post_filtered_df.drop(columns=['dominanttopic'])\n    return top_post_filtered_df\n"

# %%
app.layout = html.Div([
    html.H1('Auto Generated FAQ'),
    html.H3('Select Topics'),
    dcc.Dropdown(
        id='my-dropdown',
        options=dict_topics,
        multi=True,
        value= dict_topic_list(dict_topics)
    ),
    # html.H3('Trending Topics'),
    dcc.Graph(
        id='top_topics'
    ),
    dcc.Graph(
        id='top_topics_timeline'
    ),
    html.H1('FAQ This Week'),
    html.Table(id= 'my-table')
])


# For the top topics graph
@app.callback(Output('top_topics', 'figure'), [Input('my-dropdown', 'value')])
def update_graph(selected_dropdown_value):

    top_topic_filtered_df = top_post_df.copy()

    top_topic_filtered_df = top_post_filtered(top_topic_filtered_df, selected_dropdown_value)



    figure = {

        'data': [go.Bar(

            y=top_topic_filtered_df.dominant_topic_text.value_counts().index,

            x=top_topic_filtered_df.dominant_topic_text.value_counts().values,

            orientation='h'

        )],

        'layout':go.Layout(

            title= 'Trending Topics',

            yaxis = dict(

                # autorange=True,

                automargin=True

            )

        )

    }

    return figure



# For the top topics graph

@app.callback(Output('top_topics_timeline', 'figure'), [Input('my-dropdown', 'value')])

def update_graph(selected_dropdown_value):

    top_topic_filtered_df = top_post_df.copy()

    top_topic_filtered_df = top_post_filtered(top_topic_filtered_df, selected_dropdown_value)

    data = timeline_top_post_filtered(top_topic_filtered_df,selected_dropdown_value)

    # Edit the layout

    layout = dict(title='Top Topics Timeline',

                  xaxis=dict(title='Month'),

                  yaxis=dict(title='count posts'),

                  )

    figure = dict(data=data,layout=layout)

    return figure



@app.callback(Output('my-table', 'children'), [Input('my-dropdown', 'value')])

def generate_table(selected_dropdown_value,max_rows=10):

    top_post_filtered_df= top_post_df.copy()

    top_post_filtered_df= top_post_filtered(top_post_filtered_df,selected_dropdown_value)

    return [html.Tr([html.Th(col) for col in top_post_filtered_df.columns])] + [html.Tr([

        html.Td(html.A('click', href=top_post_filtered_df.iloc[i][col])) if col == 'url' else html.Td(

            top_post_filtered_df.iloc[i][col]) for col in top_post_filtered_df.columns

    ]) for i in range(min(len(top_post_filtered_df), max_rows))]



def convertTuple(tup):

    str =  ','.join(tup)

    return str



def top_post_filtered(top_post_filtered_df,selected_dropdown_value):

    print(selected_dropdown_value)



    # if selected_dropdown_value is None:

    #     selected_dropdown_value = dict_topics

    top_post_filtered_df['dominant_topic_text'] = top_post_df['dominanttopic'].apply(convertTuple)

    top_post_filtered_df = top_post_filtered_df[

        (top_post_filtered_df['dominant_topic_text'].isin(selected_dropdown_value))]

    top_post_filtered_df = top_post_filtered_df.drop(columns=['dominanttopic'])

    return top_post_filtered_df



def timeline_top_post_filtered(top_topic_filtered_df, selected_dropdown_value):

    # Make a timeline

    top_topic_filtered_df['timestamp'] = top_topic_filtered_df['timestamp'].apply(lambda x: pd.to_datetime(str(x)))

    topic_time_count = top_topic_filtered_df.set_index(top_topic_filtered_df.timestamp).loc[:, 'dominant_topic_text']

    trace_list = []

    for value in selected_dropdown_value:

        topic_time_filtered_count = topic_time_count[topic_time_count == value]

        topic_day_count = topic_time_filtered_count.groupby([topic_time_filtered_count.index.month]).value_counts()

        topic_day_count_df = topic_day_count.unstack(level=1)

        # print(topic_day_count_df)

        trace = go.Scatter(

            y=topic_day_count_df[value],

            x=topic_day_count_df.index,

            name = value

        )

        trace_list.append(trace)

    return trace_list
# Out:
# ['students,free,low,data,break', 'science,users,tier,break,interview', 'beware,tool,hunger,reality,vs', 'data,pandas,companies,vs,toughest', 'masters,dataframes,phd,perception,medium']

# %%
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
#  * Serving Flask app "dash" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on
#  * Restarting with stat
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# C:\Users\OM\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3334: UserWarning:
#
# To exit: use 'exit', 'quit', or Ctrl-D.
